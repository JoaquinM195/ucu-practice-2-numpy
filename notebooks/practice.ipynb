# %% [markdown]
# # Práctica de NunPy
#
# Análisis de Distribuciones Probabilísticas con NumPy y Matplotlib
#
# ## Objetivos
# - Aplicar los conceptos de generación de distribuciones aleatorias con **NumPy**.
# - Calcular los **estadísticos descriptivos** de cada distribución.
# - Representar visualmente los resultados utilizando **Matplotlib**.
#
# ---
#
# ## Indicaciones
#
# 1. **Generación de datos**
#    - Genera **dos distribuciones aleatorias** de un tamaño de 1.000 observaciones cada una:
#      - Una **Distribución Normal (Gaussiana)** con media y desvío estándar a elección.
#      - Una **Distribución Uniforme** dentro de un rango que definas.
#
# 2. **Análisis estadístico**
#    - Calcula para cada distribución los siguientes valores:
#      - Media (`mean`)
#      - Mediana (`median`)
#      - Varianza (`var`)
#      - Desvío estándar (`std`)
#      - Mínimo y máximo (`min`, `max`)
#
# 3. **Visualización**
#    - Utiliza **Matplotlib** para crear **dos subplots (gráficos)** en una misma figura:
#      - En el **subplot izquierdo**, muestra el **histograma de la distribución normal**.
#      - En el **subplot derecho**, muestra el **histograma de la distribución uniforme**.
#    - Agrega título general, etiquetas de ejes, leyenda y grilla en cada gráfico.     - Agrega título, leyenda y etiquetas de ejes.
#
# 4. **Reflexión**
#    - Describe brevemente (en una celda Markdown) las diferencias observadas entre ambas distribuciones según los resultados y el gráfico.
#
# ---
#
# ## Criterios de evaluación
# - Correcta implementación de PEP8
# - Correcto uso de celdas markdown y de código en el Jupyter Notebook.
# - Correcta implementación de las funciones de NumPy.
# - Cálculo adecuado de los estadísticos descriptivos.
# - Uso apropiado y estético de Matplotlib para la visualización.
# - Claridad en la interpretación final.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Distribución Normal
#
# Se hace el randomizador de los números para la distribución normal y posteriormente se hacen los cálculos estadísticos correspondientes

# %%
normal = np.random.normal(10,5,1000)

media_normal = np.mean(normal)
mediana_normal = np.median(normal)
varianza_normal = np.var(normal)
desvio_normal = np.std(normal)
minimo_normal = np.min(normal)
maximo_normal = np.max(normal)

# %% [markdown]
# # Distribución Uniforme
# Ídem que en la anterior pero ahora aplicado a la Distribución Uniforme

# %%
uniforme = np.random.uniform(0,20,1000)

media_uniforme = np.mean(uniforme)
mediana_uniforme = np.median(uniforme)
varianza_uniforme = np.var(uniforme)
desvio_uniforme = np.std(uniforme)
minimo_uniforme = np.min(uniforme)
maximo_uniforme = np.max(uniforme)

# %% [markdown]
# # Resultados
#
# Se muestran los resultados de los cálculos estadísticos realizados en los bloques de código anteriores

# %%
resultados = {
    "Distribución Normal": {
        "Mediana": mediana_normal,
        "Varianza": varianza_normal,
        "Desvío estándar": desvio_normal,
        "Mínimo": minimo_normal,
        "Máximo": maximo_normal
    },
    "Distribución Uniforme": {
        "Mediana": mediana_uniforme,
        "Varianza": varianza_uniforme,
        "Desvío estándar": desvio_uniforme,
        "Mínimo": minimo_uniforme,
        "Máximo": maximo_uniforme
    }
}

resultados
# Out:
# {'Distribución Normal': {'Mediana': np.float64(9.973456958172328),
#   'Varianza': np.float64(23.70576938355051),
#   'Desvío estándar': np.float64(4.8688570921264995),
#   'Mínimo': np.float64(-5.813343183548408),
#   'Máximo': np.float64(26.000094145282524)},
#  'Distribución Uniforme': {'Mediana': np.float64(9.811168668118082),
#   'Varianza': np.float64(33.14215593504494),
#   'Desvío estándar': np.float64(5.756922436080318),
#   'Mínimo': np.float64(0.04023565684619701),
#   'Máximo': np.float64(19.998082965787162)}}

# %% [markdown]
# # Gráfico
#
# Se realizan las expresiones gráficas de ambas distribuciones para una mejor apreciación de cada figura

# %%
plt.figure(figsize=(13, 8))

#Subplot izquierdo: Normal
plt.subplot(1, 2, 1)
plt.hist(normal, bins='sqrt')
plt.title("Histograma - Distribución Normal")
plt.xlabel("Contenedores, agrupaciones")
plt.ylabel("Frecuencia, cantidad")
plt.grid(axis='y')


#Subplot derecho: Uniforme
plt.subplot(1, 2, 2)
plt.hist(uniforme, bins='sqrt',color='red')
plt.title("Histograma - Distribución Uniforme")
plt.xlabel("Contenedores, agrupaciones")
plt.ylabel("Frecuencia, cantidad")
plt.grid(axis='y')

plt.suptitle("Comparación de Distribuciones", fontsize=14)
plt.tight_layout()
plt.show()
